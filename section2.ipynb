# %% [markdown]
# <h2>
#     <b>
#         <font color='#660000'>
#             Section 2: "The Fusion of Text Titans"
#         </font>
#     </b>
# </h2>
#
# What happens when texts from two different notebooks collide? An explosion of knowledge, of course! Or perhaps total confusion. Either way, we're here for it.

# %% [markdown]
# <h3>
#     <b>
#         <font color='#092A44'>
#             Chapter 1: The Unlikely Encounter
#         </font>
#     </b>
# </h3>

# %%
sec2_chap1 = """
Two notebooks,two stories. 
When worlds collide, the result is a line of code that unites what destiny had separated.
"""

print(sec2_chap1)
# Out:
# Two notebooks,two stories.
# When worlds collide, the result is a line of code that unites what destiny had separated.

# %% [markdown]
# <h3>
#     <b>
#         <font color='#092A44'>
#             Chapter 2: The Dance of Text Cells
#         </font>
#     </b>
# </h3>

# %%
sec2_chap2 = """
Like an awkward choreographer,
Our code attempts to find the perfect rhythm so that each text cell
finds its place in the digital dance of unity.
"""

print(sec2_chap2)
# Out:
# Like an awkward choreographer,
# Our code attempts to find the perfect rhythm so that each text cell
# finds its place in the digital dance of unity.
